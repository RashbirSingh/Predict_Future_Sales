# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # File descriptions
# * **sales_train.csv** - the training set. Daily historical data from January 2013 to October 2015.
# * **test.csv** - the test set. You need to forecast the sales for these shops and products for November 2015.
# * **sample_submission.csv** - a sample submission file in the correct format.
# * **items.csv** - supplemental information about the items/products.
# * **item_categories.csv**  - supplemental information about the items categories.
# * **shops.csv**- supplemental information about the shops.
#
# # Data fields
# * **ID** - an Id that represents a (Shop, Item) tuple within the test set
# * **shop_id** - unique identifier of a shop
# * **item_id** - unique identifier of a product
# * **item_category_id** - unique identifier of item category
# * **item_cnt_day** - number of products sold. You are predicting a monthly amount of this measure
# * **item_price** - current price of an item
# * **date** - date in format dd/mm/yyyy
# * **date_block_num** - a consecutive month number, used for convenience. January 2013 is 0, February 2013 is 1,..., October 2015 is 33
# * **item_name** - name of item
# * **shop_name** - name of shop
# * **item_category_name** - name of item category

# %% [markdown]
# # Reading Data Set

# %%
sales_train = pd.read_csv("sales_train.csv")
items = pd.read_csv("items.csv")
item_categories = pd.read_csv("item_categories.csv") 
shops = pd.read_csv("shops.csv")

# %% [markdown]
# # Getting basic insight of data frames

# %%
print(" sales_train -> ", sales_train.shape, "\n",
     "items -> ", items.shape, "\n",
     "item_categories -> ", item_categories.shape, "\n",
     "shops -> ", shops.shape)
# Out:
#  sales_train ->  (2935849, 6)
#  items ->  (22170, 3)
#  item_categories ->  (84, 2)
#  shops ->  (60, 2)

# %% [markdown]
# ### ----------------------------------------->>     sales_train  <<------------------------------------------------------###

# %%
sales_train.columns, len(sales_train.columns)
# Out:
# (Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#         'item_cnt_day'],
#        dtype='object'), 6)

# %%
sales_train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
sales_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
# date              object
# date_block_num    int64
# shop_id           int64
# item_id           int64
# item_price        float64
# item_cnt_day      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
sales_train.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03

# %% [markdown]
# ### ----------------------------------------->>     items    <<------------------------------------------------------###

# %%
items.columns, len(items.columns)
# Out:
# (Index(['item_name', 'item_id', 'item_category_id'], dtype='object'), 3)

# %%
items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22170 entries, 0 to 22169
# Data columns (total 3 columns):
# item_name           22170 non-null object
# item_id             22170 non-null int64
# item_category_id    22170 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 519.7+ KB

# %%
items.describe()
# Out:
#            item_id  item_category_id
# count  22170.00000      22170.000000
# mean   11084.50000         46.290753
# std     6400.07207         15.941486
# min        0.00000          0.000000
# 25%     5542.25000         37.000000
# 50%    11084.50000         40.000000
# 75%    16626.75000         58.000000
# max    22169.00000         83.000000

# %% [markdown]
# ### ----------------------------------------->>     item_categories    <<------------------------------------------------------###

# %%
item_categories.columns, len(item_categories.columns)
# Out:
# (Index(['item_category_name', 'item_category_id'], dtype='object'), 2)

# %%
item_categories.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
item_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
# item_category_name    84 non-null object
# item_category_id      84 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
item_categories.describe()
# Out:
#        item_category_id
# count         84.000000
# mean          41.500000
# std           24.392622
# min            0.000000
# 25%           20.750000
# 50%           41.500000
# 75%           62.250000
# max           83.000000

# %% [markdown]
# ### ----------------------------------------->>     shops    <<------------------------------------------------------###

# %%
shops.columns, len(shops.columns)
# Out:
# (Index(['shop_name', 'shop_id'], dtype='object'), 2)

# %%
shops.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
shops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
# shop_name    60 non-null object
# shop_id      60 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB

# %%
shops.describe()
# Out:
#          shop_id
# count  60.000000
# mean   29.500000
# std    17.464249
# min     0.000000
# 25%    14.750000
# 50%    29.500000
# 75%    44.250000
# max    59.000000

# %% [markdown]
# ### Concatinating dataframes

# %%
sales_train.merge(items, on="item_id")
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1
1.0                                  ЯВЛЕНИЕ 2012 (BD)
# 29                1.0                                  ЯВЛЕНИЕ 2012 (BD)
# ...               ...                                                ...
# 2935819           1.0                                   QUEEN  Queen  LP
# 2935820           1.0                      QUEEN  Sheer Heart Attack  LP
# 2935821           1.0        ДЕТЯМ  Ударцев Виктор  Новогодняя дискотека
# 2935822           1.0                                 ВРЕМЕННО БЕРЕМЕННА
# 2935823           1.0  1С:Аудиокниги. Добрыня Никитич и Змей Горыныч....
# 2935824           1.0  1С:Аудиокниги. Добрыня Никитич и Змей Горыныч....
# 2935825           1.0                                  38 ПОПУГАЕВ (rem)
# 2935826           1.0  1С:Аудиотеатр. Ф.М. Достоевский. Идиот. (Digip...
# 2935827           1.0  Набор кружек Star Wars Darth Vader, Stormtroop...
# 2935828           1.0                      Настольная игра Дикие джунгли
# 2935829           1.0      Мягкая игрушка Обезьянка Вика в носочках 23см
# 2935830           1.0                 Футболка Darksiders The Horseman M
# 2935831           1.0  1С:Аудиокниги. А.М. Волков. Волшебник изумрудн...
# 2935832           1.0  1С:Аудиокниги. Марк твен. Приключения Гекльбер...
# 2935833           1.0        1С:Аудиотеатр. Полезные загадки. (Digipack)
# 2935834           1.0  1С:Электронное обучение. Разработка электронны...
# 2935835           1.0           Turbo Games. Тайна рифа (PC-DVD) (Jewel)
# 2935836           2.0        Мягкая игрушка Обезьянка Валек в шапке 20см
# 2935837          -1.0  Комплект «Sony PS3 (320 Gb) (CECH-2508B)» + иг...
# 2935838           1.0  Комплект «Sony PS3 (320 Gb) (CECH-2508B)» + иг...
# 2935839           1.0  Комплект «Sony PS3 (320 Gb) (CECH-2508B)» + иг...
# 2935840           1.0  Комикс Моя мама в Америке, она видела Буффало ...
# 2935841           1.0                             Настольная игра Звонго
# 2935842           1.0                           Настольная игра Диксит 1
# 2935843           1.0               МОЙ МАЛЕНЬКИЙ ПОНИ  Подарочный набор
# 2935844           1.0                       АХ, ВОДЕВИЛЬ, ВОДЕВИЛЬ (rem)
# 2935845           1.0  XBOX 360 S 250GB CONSOLE/KINECT BUNDLE KUNG FU...
# 2935846           1.0      WARHAMMER ACCESSORIES: Khorne Dice арт. 65-13
# 2935847           1.0  WARHAMMER MINIATURES: Dark Elf Doomfire Warloc...
# 2935848           1.0  WARHAMMER MINIATURES: Stormcast Eternals Palad...
#
#          item_category_id
# 0                      37
# 1                      37
# 2                      37
# 3                      37
# 4                      37
# 5                      37
# 6                      37
# 7                      37
# 8                      37
# 9                      37
# 10                     37
# 11                     37
# 12                     37
# 13                     37
# 14                     37
# 15                     37
# 16                     37
# 17                     37
# 18                     37
# 19                     37
# 20                     37
# 21                     37
# 22                     37
# 23                     37
# 24                     37
# 25                     37
# 26                     37
# 27                     37
# 28                     37
# 29                     37
# ...                   ...
# 2935819                58
# 2935820                58
# 2935821                55
# 2935822                40
# 2935823                45
# 2935824                45
# 2935825                40
# 2935826                45
# 2935827                69
# 2935828                64
# 2935829                63
# 2935830                61
# 2935831                45
# 2935832                45
# 2935833                45
# 2935834                77
# 2935835                30
# 2935836                63
# 2935837                11
# 2935838                11
# 2935839                11
# 2935840                47
# 2935841                64
# 2935842                64
# 2935843                40
# 2935844                40
# 2935845                15
# 2935846                64
# 2935847                64
# 2935848                64
#
# [2935849 rows x 8 columns]
